# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r'C:\Users\zzsgdsg7\Desktop\KNN_data1.csv'
data = pd.read_csv(path,parse_dates=True,index_col='time')
print(data.head())
# Out:
#                      so2   no2  pm10  pm2.5    o3   co  temperature  humidity  \
# time
# 2019-04-16 00:00:00  5.0  75.0  61.0   38.0   1.0  1.0         21.1      89.0
# 2019-04-16 01:00:00  5.0  64.0  60.0   41.0  25.0  0.8         20.4      92.0
# 2019-04-16 02:00:00  4.0  60.0  36.0   40.0  25.0  0.8         20.0      93.0
# 2019-04-16 03:00:00  4.0  39.0  35.0   33.0  41.0  0.7         19.8      93.0
# 2019-04-16 04:00:00  4.0  39.0  28.0   39.0  36.0  0.8         19.9      92.0
#
#                      pressure  wind
# time
# 2019-04-16 00:00:00    1013.0   1.2
# 2019-04-16 01:00:00    1012.4   1.1
# 2019-04-16 02:00:00    1011.3   1.1
# 2019-04-16 03:00:00    1010.4   1.5
# 2019-04-16 04:00:00    1010.0   1.5

# %%
data.plot(subplots=True, figsize=(10,12))
# Out:
# array([<AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>,
#        <AxesSubplot:xlabel='time'>, <AxesSubplot:xlabel='time'>],
#       dtype=object)

# %%
month_data = data.resample("M").mean()
#so2 = month_data.iloc[:,1]
#print(month_data)
month_data.plot(subplots=True, figsize=(10,12))
plt.savefig( r'C:\Users\zzsgdsg7\Desktop\season.pdf')
